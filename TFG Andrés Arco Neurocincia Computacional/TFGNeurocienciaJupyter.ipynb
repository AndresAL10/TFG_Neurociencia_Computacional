# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # TFG Neurociencia
# ## Simulaciones en diferentes puntos de relevancia

# %% [markdown]
# ### 1. Prueba en una simulación con los parámetros estándar

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
data = pickle.load(open( '../Prueba 1/trial_0_rate_1.5.AMPA',"rb"),encoding='latin1' )
data1 = pickle.load(open( '../Prueba 1/trial_0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(data[100:999]) + abs(data1[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 1.2. Representación de los spikes

# %%
data = pickle.load(open( '../Prueba 1/trial_0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Estándar")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 2.1 Prueba en una simulación con parámetros exc_exc = 0.005

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.005)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.005)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 2.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.005)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Exc_exc(0.005)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 3.1. Prueba en una simulación con parámetros exc_exc = 0.200

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.200)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.200)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 3.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.200)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Exc_exc(0.200)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 4.1. Prueba en una simulación con parámetros exc_exc = 0.450

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.450)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.450)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 4.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.450)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Exc_exc(0.450)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 5.1. Prueba en una simulación con parámetros inh_exc = -0.25

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-0.25)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-0.25)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 5.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-0.25)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Inh_exc(-0.25)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 6.1. Prueba en una simulación con parámetros inh_exc = -2.00

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-2.00)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-2.00)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 6.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-2.00)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Inh_exc(-2.00)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 7.1. Prueba en una simulación con parámetros inh_exc = -4.50

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-4.50)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-4.50)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 7.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-4.50)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Inh_exc(-4.50)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ### 8.1. Prueba en una simulación con parámetros inh_exc = -8.00

# %%
fig = plt.figure(figsize=[9,4], dpi=120)
dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-8.00)-1-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-8.00)-1-0_rate_1.5.GABA',"rb"),encoding='latin1' )
x = np.arange(1,900)
y = abs(dataAMPA[100:999]) + abs(dataGABA[100:999])

plt.title("|AMPA| + |GABA|")
plt.xlabel("time (ms)")
plt.ylabel("EEG amplitude")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 8.2. Representación de los spikes

# %%
data = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_inh_exc_recurrent(-8.00)-1-0_rate_1.5.spikes',"rb"),encoding='latin1' )

fig = plt.figure(figsize=[8,6], dpi=100)
Vax = fig.add_axes([0.15,0.15,0.8,0.8],frameon=True)
for k in range(5000):
     if 100< k < 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color='b',label = 'Exc.')
     if k>= 4000:
         Vax.scatter(data[k],k*np.ones(len(data[k])),s=0.2,color = 'r',label = 'Inh.')

Vax.set_title("Spikes Inh_exc(-8.00)")
Vax.set_xlim([0.0,900.0])
Vax.set_xlabel('Time (ms)')
Vax.set_ylabel('Cell ID')

Vax = fig.add_axes([0.8,0.15,0.1,0.7],frameon=False)
for k in range(2):
    if k==0:
        Vax.plot([],[],'o',color='b',label = 'Exc.')
    else:
        Vax.plot([],[],'o',color = 'r',label = 'Inh.')

Vax.set_yticks([])
Vax.set_xticks([])
Vax.legend(loc='upper right')

# %% [markdown]
# ## Lista con todos los valores del EEG (|AMPA| + |GABA|) y el radio de conductancias g (g_exc/g_inh)

# %%
#30 exc_exc y 30 exc_inh

X = []
for trial in range(3):
    for k in np.arange(0,0.25,0.025):
        if(k==0):
            dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.005)-'+str(trial+1)+'-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
            dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent(0.005)-'+str(trial+1)+'-0_rate_1.5.GABA',"rb"),encoding='latin1' )
            X.append(abs(dataAMPA[100:999]) + abs(dataGABA[100:999]))
        else:
            dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent('+"{:.3f}".format(k)+')-'+str(trial+1)+'-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
            dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_exc_recurrent('+"{:.3f}".format(k)+')-'+str(trial+1)+'-0_rate_1.5.GABA',"rb"),encoding='latin1' )
            X.append(abs(dataAMPA[100:999]) + abs(dataGABA[100:999]))

for trial in range(3):
    for k in np.arange(0,0.30,0.030):
        if(k==0):
            dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_inh_recurrent(0.005)-'+str(trial+1)+'-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
            dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_inh_recurrent(0.005)-'+str(trial+1)+'-0_rate_1.5.GABA',"rb"),encoding='latin1' )
            X.append(abs(dataAMPA[100:999]) + abs(dataGABA[100:999]))
        else:
            dataAMPA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_inh_recurrent('+"{:.3f}".format(k)+')-'+str(trial+1)+'-0_rate_1.5.AMPA',"rb"),encoding='latin1' )
            dataGABA = pickle.load(open( '../Results/AMPA, GABA y spikes/trial_exc_inh_recurrent('+"{:.3f}".format(k)+')-'+str(trial+1)+'-0_rate_1.5.GABA',"rb"),encoding='latin1' )
            X.append(abs(dataAMPA[100:999]) + abs(dataGABA[100:999]))

#g = g_exc/g_inh
inv_g_inh = 0.233
g_exc = 0.178
Y = [inv_g_inh* 0.005,
inv_g_inh* 0.025,
inv_g_inh* 0.050,
inv_g_inh* 0.075,
inv_g_inh* 0.100,
inv_g_inh* 0.125,
inv_g_inh* 0.150,
inv_g_inh* 0.175,
inv_g_inh* 0.200,
inv_g_inh* 0.225,
inv_g_inh* 0.005,
inv_g_inh* 0.025,
inv_g_inh* 0.050,
inv_g_inh* 0.075,
inv_g_inh* 0.100,
inv_g_inh* 0.125,
inv_g_inh* 0.150,
inv_g_inh* 0.175,
inv_g_inh* 0.200,
inv_g_inh* 0.225,
inv_g_inh* 0.005,
inv_g_inh* 0.025,
inv_g_inh* 0.050,
inv_g_inh* 0.075,
inv_g_inh* 0.100,
inv_g_inh* 0.125,
inv_g_inh* 0.150,
inv_g_inh* 0.175,
inv_g_inh* 0.200,
inv_g_inh* 0.225,
g_exc/ 0.005,
g_exc/ 0.030,
g_exc/ 0.060,
g_exc/ 0.090,
g_exc/ 0.120,
g_exc/ 0.150,
g_exc/ 0.180,
g_exc/ 0.210,
g_exc/ 0.240,
g_exc/ 0.270,
g_exc/ 0.005,
g_exc/ 0.030,
g_exc/ 0.060,
g_exc/ 0.090,
g_exc/ 0.120,
g_exc/ 0.150,
g_exc/ 0.180,
g_exc/ 0.210,
g_exc/ 0.240,
g_exc/ 0.270,
g_exc/ 0.005,
g_exc/ 0.030,
g_exc/ 0.060,
g_exc/ 0.090,
g_exc/ 0.120,
g_exc/ 0.150,
g_exc/ 0.180,
g_exc/ 0.210,
g_exc/ 0.240,
g_exc/ 0.270,]

# %%
plt.plot(X[10])
np.shape(Y)
# Out:
# (60,)

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation via sklearn
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
 
# Function to create model, required for KerasClassifier
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, activation='relu'))
	model.add(Dense(8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\TFGNeurociencia\ScriptsPY\TFGNeurocienciaJupyter.ipynb Cell 38 in <module>
#       <a href='vscode-notebook-cell:/c%3A/TFGNeurociencia/ScriptsPY/TFGNeurocienciaJupyter.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> # MLP for Pima Indians Dataset with 10-fold cross validation via sklearn
# ----> <a href='vscode-notebook-cell:/c%3A/TFGNeurociencia/ScriptsPY/TFGNeurocienciaJupyter.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> from tensorflow.keras.models import Sequential
#       <a href='vscode-notebook-cell:/c%3A/TFGNeurociencia/ScriptsPY/TFGNeurocienciaJupyter.ipynb#X52sZmlsZQ%3D%3D?line=2'>3</a> from tensorflow.keras.layers import Dense
#       <a href='vscode-notebook-cell:/c%3A/TFGNeurociencia/ScriptsPY/TFGNeurocienciaJupyter.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> from scikeras.wrappers import KerasClassifier
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
#Repetir 10 veces
avg_result = 0
for fold in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)
    #
    # plt.scatter(fold*np.ones(len(y_test)),y_test)

    #Escalado de la entrada
    scaler = MinMaxScaler()
    scaler.fit(X_train)
    X_test = scaler.transform(X_test)
    X_train = scaler.transform(X_train)

    #Entrenamiento del modelo
    reg = LinearRegression().fit(X_train,y_train)
    #Probar tambien con ridge regression variar coeficiente de alfa
    #LASSO linear regression
    
    #Probar non linear ML Algorithm
    #k-Nearest neightbour
    #red neuronal



    #Predicciones
    y_pred = reg.predict(X_test)

    #Evaluacion del modelo
    result = mean_squared_error(y_test, y_pred)
    print(result)
    plt.scatter(y_test,y_pred)
    plt.plot(np.arange(0,np.max(y_pred)), np.arange(0,np.max(y_pred)), '--')
    plt.xlabel("Reales")
    plt.ylabel("Predicciones")
    plt.show()
    avg_result += result
avg_result/=10
print("Media")
print(avg_result)

# %%
#sacar las features
#autocorrelation
#transformada de welch (scipy.signal.welch(X,fs=1000)) calcular la pendiente

# %%
print(Y)
